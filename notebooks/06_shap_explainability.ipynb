# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import shap
import joblib

# %%
df=pd.read_csv(
    "../data/processed/hyderabad_cleaned.csv"
)

# %%
model=joblib.load(
    "../models/random_forest.pkl"
)

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['area', 'no_of_bedrooms',
#                                                    'resale', 'maintenancestaff',
#                                                    'gymnasium', 'swimmingpool',
#                                                    'landscapedgardens',
#                                                    'joggingtrack',
#                                                    'rainwaterharvesting',
#                                                    'indoorgames',
# ...

# %%
X=df.drop(
    columns=[
        "price",
        "log_price"
    ],
    errors="ignore"
)

# %%
X_sample=X.sample(
    1000,
    random_state=42
)

# %%
X_transformed=model.named_steps['preprocessor'].transform(X_sample)
X_transformed=X_transformed.toarray()

# %%
rf_model=model.named_steps['model']

# %%
explainer=shap.TreeExplainer(
    rf_model
)

# %%
shap_values = explainer.shap_values(
    X_transformed
)

# %%
shap.summary_plot(
    shap_values,
    X_transformed,
    show=False
)
plt.savefig(
    "../images/shap_summary.png",
    bbox_inches="tight"
)
plt.show()

# %%
shap.force_plot(
    explainer.expected_value,
    shap_values[0],
    matplotlib=True,
    show=False
)
plt.savefig(
    "../images/shap_local_explanation.png",
    bbox_inches="tight"
)

plt.show()

# %%
numerical_features=X.select_dtypes(include=np.number).columns.tolist()

# %%
categorical_features=X.select_dtypes(exclude=np.number).columns.tolist()

# %%
encoded_features = list(

    model.named_steps[
        "preprocessor"
    ]
    .named_transformers_[
        "cat"
    ]
    .named_steps[
        "encoder"
    ]
    .get_feature_names_out(
        categorical_features
    )
)

# %%
all_features=(numerical_features+categorical_features)

# %%
feature_names = model.named_steps[
    "preprocessor"
].get_feature_names_out()

# %%
print(len(feature_names))

print(X_transformed.shape)
# Out:
# 230
# (1000, 230)

# %%
print(len(all_features))

print(X_transformed.shape)
# Out:
# 42
# (1000, 230)

# %%
shap.summary_plot(

    shap_values,

    X_transformed,

    feature_names=feature_names,

    show=False
)
plt.savefig(
    '../images/shap_summary_named.png'
)
plt.show()

# %%
shap_importance=np.abs(
    shap_values
).mean(axis=0)

shap_df = pd.DataFrame({

    "Feature": feature_names,

    "SHAP_Importance": shap_importance
})

# %%
shap_df.sort_values(

    by="SHAP_Importance",

    ascending=False
).head(20)
# Out:
#                          Feature  SHAP_Importance
# 0                      num__area         0.421554
# 38                 num__latitude         0.051648
# 5              num__swimmingpool         0.033717
# 39                num__longitude         0.026770
# 13                      num__atm         0.013305
# 2                    num__resale         0.006822
# 123       cat__location_Kondapur         0.006494
# 109  cat__location_Jubilee Hills         0.005419
# 65   cat__location_Banjara Hills         0.004367
# 6         num__landscapedgardens         0.003601
# 4                 num__gymnasium         0.003520
# 102    cat__location_Hitech City         0.003329
# 178    cat__location_Puppalaguda         0.003187
# 154         cat__location_Nagole         0.003093
# 17              num__powerbackup         0.002998
# 14                num__clubhouse         0.002905
# 69      cat__location_Beeramguda         0.002880
# 12           num__sportsfacility         0.002599
# ...

# %%
shap_df.to_csv(
    "../reports/shap_feature_importance.csv",
    index=False
)

# %%
shap.force_plot(

    explainer.expected_value,

    shap_values[0],

    feature_names=feature_names,

    matplotlib=True,

    show=False
)
plt.savefig(
    "../images/shap_local_named_explanation.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Hour 4 Conclusions
#
# 1. SHAP explainability was applied to the Random Forest apartment price model.
# 2. Global explanations identified the most influential pricing features.
# 3. Local explanations showed how individual apartment characteristics affected predictions.
# 4. Geolocation and apartment area strongly influenced model outputs.
# 5. SHAP improved model transparency and interpretability.
# 6. Explainable AI techniques enhanced trustworthiness of predictions.
